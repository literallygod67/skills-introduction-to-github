# %% [markdown]
# # Run this cell first

# %%
# this code enables the automated feedback. If you remove this, you won't get any feedback
# so don't delete this cell!
try:
  import AutoFeedback
except (ModuleNotFoundError, ImportError):
  # %pip install AutoFeedback
  import AutoFeedback

try:
  from testsrc import test_main
except (ModuleNotFoundError, ImportError):
  # %pip install "git+https://github.com/autofeedback-exercises/exercises.git#subdirectory=MTH1025/intro/Calculation-Basics"
  from testsrc import test_main

def runtest():
  import unittest
  from contextlib import redirect_stderr
  from os import devnull
  with redirect_stderr(open(devnull, 'w')):
    unittest.main(argv=[''], module=test_main, exit=False)

# %% [markdown]
# # Calculation_Basics
# For each of the following expressions define a variable with the given name, and set the value accordingly.
# The first one has been completed so you can see the required syntax
#
# * $q0 = \sin\left(\dfrac{\pi}{4}\right)$
#
# * $q1 = \dfrac{3^4+7^5}{36^2-1}$
#
# * $q2 = \dfrac{4}{3}\pi r^3$ where $r=3^{1/5}$
#
# * $q3 = \sin\left(\dfrac{5\pi}{6}\right)$
#
# * $q4 = \sin^2\left(\dfrac{\pi}{5}\right)+\cos^2\left(\dfrac{\pi}{5}\right)$
#
# * $q5 = e^5$
#
# * $q6 = \log_{10} \left(10^3\right)$

# %%
import numpy as np

# This first variable is defined as an example
q0 = np.sin(np.pi/4)
print(q0)
q1 = (3**4 + 7**5) / (36**2 - 1)
print(q1)
r = 3**(1/5)
q2 = (4/3)*(np.pi)*(r**3)
print (q2)
q3 = np.sin((5*np.pi)/6)
print(q3)
q4 = (np.sin((np.pi)/5))**2 + (np.cos((np.pi)/5))**2
print(q4)
q5 = np.e**5
print(q5)
q6 = np.log10(10**3)
print(q6)

# %%
runtest()
